# %% [markdown]
# # **Data Visualization Techniques 👨🏻‍💻**
# ---
# ### Agenda
# * [Data Visualization](#Data_Visualization)
# * [Importing Dataset](#Dataset)
# * [Scatter Plot](#scatter)
# * [Line Plot](#line)
# * [Histogram Plot](#histogram)
# * [Bar Plot](#bar)
# * [Pie Plot](#pie)
# * [Stem Plot](#stem)

# %% [markdown]
# ## <a id='Data_Visualization'></a>Data Visualization 🤔
# ---
# Data visualization is the graphical representation of information and data. Using visual elements such as charts, graphs, and maps, data visualization tools provide an accessible way to see and understand trends, outliers, and patterns in data.
#
# In the world of big data, data visualization tools and techniques are essential for analyzing vast amounts of information and making data-driven decisions.
#
# - **For a simple overview, here are some popular plotting libraries:**
#
#    - [Matplotlib](https://matplotlib.org/): Low level, provides a lot of freedom.
#
#    - [Pandas visualization](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html): an easy-to-use interface, built on Matplotlib.
#
#    - [Seaborn](https://seaborn.pydata.org/): High-level interface, cool virtual styles.

# %% [markdown]
# ## Importing libraries 📥
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## <a id='Dataset'></a>Importing Datasets 📂
# ---
# In this exercise, we will use the **Iris** dataset which we can load using pandas.
#
# - The **Iris** dataset includes three iris species with 50 samples each as well as some properties about each flower. One flower species is linearly separable from the other two, but the other two are not linearly separable from each other.
#
#     - **The columns in this dataset are**:
#         - Id
#         - SepalLengthCm
#         - SepalWidthCm
#         - PetalLengthCm
#         - PetalWidthCm
#         - Species
#
#
#
# - The **Placement** dataset consists of Placement data of students in campus. It includes secondary and higher secondary school percentage and specialization. It also includes degree specialization, type and Work experience and salary offers to the placed students

# %%
# Read Iris dataset
iris = pd.read_csv('Data/Iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Read Placement dataset
cp = pd.read_csv("Data/Placement_data_full_class.csv")
cp.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %% [markdown]
# ---
# ## <a id='scatter'></a>Scatter Plot 🤔
#
# - To generate a scatter plot in **Matplotlib** we can use the `scatter` method. We will also create a figure and axis with `plt.subplots` so we can give our title and labels.
#
#
# - To create a scatter plot in **Pandas**, we can call `<dataset>.plot.scatter()` and pass two arguments, column name x as well as column name y. Optionally we can also pass an title to it.
#
#
# - We can use the `.scatterplot` method to create a scatter plot in **Seaborn**, and just like in Pandas we need to pass the column names of x and y data, but now we also need to pass the data as an extra argument because we don't call the function on the data directly like we did in Pandas.
#
# ---
#
# - Exercise 1 (Scatter Plot using Matplotlib)
# - Exercise 2 (Scatter Plot using Pandas visualization)
# - Exercise 3 (Scatter Plot using Seaborn)

# %% [markdown]
# ### Exercise 1 (Scatter Plot using Matplotlib) 👇
# ---

# %%
####################################### Scatter Plot using Matplotlib #########################################

color=np.random.randint(0,10,150)
# scatter the SepalLengthCm against the SepalWidthCm
plt.scatter(iris['SepalLengthCm'], iris['SepalWidthCm'],
            s=150,   # Size
            c=color, # Sequence of n numbers to be mapped to colors using cmap
            cmap="Reds", # Instance colormap name. cmap is only used if c is an array of floats.
            edgecolor="black", # The edge color of the marker
            linewidth=1, # The linewidth of the marker edges
            alpha=1) # The alpha blending value

cbar=plt.colorbar()
# set a title and labels
plt.title('Iris Dataset')
plt.xlabel('SepalLengthCm')
plt.ylabel('SepalWidthCm')
# Out:
# Text(0, 0.5, 'SepalWidthCm')

# %%
colors = {'Iris-setosa':'b', 'Iris-versicolor':'tab:orange', 'Iris-virginica':'g'}
colors['Iris-setosa']
# Out:
# 'b'

# %% [markdown]
# **Note**: We can give the graph more meaning by coloring each data point with its category.👌

# %%
# create color dictionary
colors = {'Iris-setosa':'b', 'Iris-versicolor':'tab:orange', 'Iris-virginica':'g'}
# create a figure and axis
fig, ax = plt.subplots()
# plot each data-point
for i in range(len(iris['SepalLengthCm'])):
    ax.scatter(iris['SepalLengthCm'][i], iris['SepalWidthCm'][i],color=colors[iris['Species'][i]],
            s=150,   # Size
            edgecolor="black", # The edge color of the marker
            linewidth=1, # The linewidth of the marker edges
            alpha=1)   # The alpha blending value)
# set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('SepalLengthCm')
ax.set_ylabel('SepalWidthCm')
# Out:
# Text(0, 0.5, 'SepalWidthCm')

# %% [markdown]
# ### Exercise 2 (Scatter Plot using Pandas visualization) 👇
# ---

# %%
#################################### Scatter Plot using Pandas visualization #####################################

color=np.random.randint(0,10,150)

# scatter the SepalLengthCm against the SepalWidthCm
iris.plot.scatter(x='SepalLengthCm', y='SepalWidthCm',
            s=150,   # Size
            c=color, # Sequence of n numbers to be mapped to colors using cmap
            cmap="Reds", # Instance colormap name. cmap is only used if c is an array of floats.
            edgecolor="black", # The edge color of the marker
            linewidth=1, # The linewidth of the marker edges
            alpha=1, # The alpha blending value
            title='Iris Dataset')
# Out:
# <AxesSubplot:title={'center':'Iris Dataset'}, xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# ### Exercise 3 (Scatter Plot using Seaborn) 👇
# ---

# %%
####################################### Scatter Plot using Seaborn #########################################

# scatter the SepalLengthCm against the SepalWidthCm
ax = sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', data=iris,
            s=150,   # Size
            c=color, # Sequence of n numbers to be mapped to colors using cmap
            cmap="Reds", # Instance colormap name. cmap is only used if c is an array of floats.
            edgecolor="black", # The edge color of the marker
            linewidth=1, # The linewidth of the marker edges
            alpha=1) # The alpha blending value
ax.set_title('Iris Dataset')
# Out:
# Text(0.5, 1.0, 'Iris Dataset')

# %% [markdown]
# **Note**: We can give the graph more meaning by coloring each data point with its category 👌.

# %%
ax = sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species', data=iris,
            s=150,   # Size
            edgecolor="black", # The edge color of the marker
            linewidth=1, # The linewidth of the marker edges
            alpha=1) # The alpha blending value

ax.set_title('Iris Dataset')
# Out:
# Text(0.5, 1.0, 'Iris Dataset')

# %% [markdown]
# ## <a id='line'></a>Line Plot 📈 📉
# ---
#
# - In **Matplotlib** we can create a line plot by calling the `plot` method. We can also plot multiple columns in a single graph, by looping through the columns we want and plotting each column on the same axis.
#
#
# - To create a line plot in **Pandas**, we can call `<dataframe>.plot.line()`. While in Matplotlib we needed to loop over every column we wanted to plot, in Pandas we don't need to do that because it automatically plots all available numeric columns (at least if we don't define a specific column/s).
#
#
# - To create a line plot in **Seaborn**, the `sns.lineplot` method can be used. The only argument required is the data, which in our case is the four numeric columns from the Iris dataset. We can also use the `sns.kdeplot` method which goes around the edges of the curves, so it's much cleaner if you have a lot of outliers in your dataset.
#
# ---
# - Exercise 4  (Line Plot using Matplotlib)
# - Exercise 5 (Line Plot using Pandas visualization)
# - Exercise 6 (Line Plot using Seaborn)
# - Now Your Turn 💪💪
# ---

# %% [markdown]
# ### Exercise 4 (Line Plot using Matplotlib) 👇
# ---

# %%
####################################### Line Plot using Matplotlib #########################################
# get columns to plot
columns = iris.columns.drop(['Id','Species'])
# create x data
x_data = range(0, iris.shape[0])
# create figure and axis
fig, ax = plt.subplots()
# plot each column
for column in columns:
    ax.plot(x_data, iris[column], label=column)
# set title and legend
ax.set_title('Iris Dataset')
ax.legend()

# %% [markdown]
# ### Exercise 5 (Line Plot using Pandas visualization) 👇
# ---

# %%
#################################### Line Plot using Pandas visualization #####################################
iris.drop(['Id','Species'], axis=1).plot.line(title='Iris Dataset')
# Out:
# <AxesSubplot:title={'center':'Iris Dataset'}>

# %% [markdown]
# ### Exercise 6 (Line Plot using Seaborn) 👇
# ---

# %%
####################################### Line Plot using Seaborn #########################################
sns.lineplot(data=iris.drop(['Id','Species'], axis=1))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### ⟹ Now Your Turn 💪💪🚀
# ---
# - Use the `company_sales_data.csv` CSV file for this exercise.
# - Read Total profit of all months and show it using a line plot.
# - Read toothpaste sales data of each month and show it using a scatter plot.

# %%
#### Read Read this file using Pandas
df = pd.read_csv("Data/company_sales_data.csv")
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
# Write Your code 🚀🚀

### Read Total profit of all months
# Start code
import pandas as pd
import matplotlib.pyplot as plt  

profitList = df ['total_profit'].tolist()
monthList  = df ['month_number'].tolist()
plt.plot(monthList, profitList, label = 'Month-wise Profit data of last year')
plt.xlabel('Month number')
plt.ylabel('Profit in dollar')
plt.xticks(monthList)
plt.title('Company profit per month')
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show()

#========================================================================================================

### Read toothpaste sales data of each month
# Start code
import pandas as pd
import matplotlib.pyplot as plt  

monthList  = df ['month_number'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
plt.scatter(monthList, toothPasteSalesData, label = 'Tooth paste Sales data')
plt.xlabel('Month Number')
plt.ylabel('Number of units Sold')
plt.legend(loc='upper left')
plt.title(' Tooth paste Sales data')
plt.xticks(monthList)
plt.grid(True, linewidth= 1, linestyle="--")
plt.show()
# End code

### Show toothpaste sales data of each month using a scatter plot.
# Start code

# End code

# %% [markdown]
# #           ****************                               *****************
# #                              🥳🥳   Break 🥳🥳
#
# #           ****************                               *****************

# %% [markdown]
# ---
# ## <a id='histogram'></a>Histogram Plot 🤔
#
# - In **Matplotlib** we can create a Histogram using the `hist` method. If we pass it categorical data like the points column from the wine-review dataset it will automatically calculate how often each class occurs.
#
#
# - In **Pandas**, we can create a Histogram with the `plot.hist` method. There aren’t any required arguments but we can optionally pass some like the bin size.
#
#
# - To create a histogram in **Seaborn**, we use the `sns.distplot` method. We need to pass it in the column we want to plot and iit will calculate the occurrences itself. We can also pass the number of bins to it.
#
# ---
#
# - Exercise 7 (Histogram Plot using Matplotlib)
# - Exercise 8 (Histogram Plot using Pandas visualization)
# - Exercise 9 (Histogram Plot using Seaborn)
# ---

# %% [markdown]
# ### Exercise 7 (Histogram Plot using Matplotlib) 👇
# ---

# %%
####################################### Histogram Plot using Matplotlib #########################################

# create figure and axis
fig, ax = plt.subplots()
# plot histogram
ax.hist(cp['salary'], edgecolor="black", color="r")
# set title and labels
ax.set_title('Salary Frequency')
ax.set_xlabel('Salary')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Exercise 8 (Histogram Plot using Pandas visualization) 👇
# ---

# %%
cp.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
#################################### Histogram Plot using Pandas visualization #####################################

ax = cp['salary'].plot.hist(edgecolor="black", color="r")
ax.set_title('Salary Frequency')
ax.set_xlabel('Salary')
# Out:
# Text(0.5, 0, 'Salary')

# %% [markdown]
# ### Exercise 9 (Histogram Plot using Seaborn) 👇
# ---

# %%
####################################### Histogram Plot using Seaborn #########################################



sns.histplot(cp['salary'], bins=10, kde=True, color='r')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %%
sns.distplot(cp['salary'], bins=10, kde=True, color='r')
# Out:
# C:\Users\h.eloqool.ext\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %% [markdown]
# ---
# ## <a id='bar'></a>Bar Plot 📊
#
# - A bar chart can be created in **Matplotlib** using the `bar` method. The bar chart does not automatically calculate the frequency of a category, so we will use the pandas value_counts function to do this. A bar chart is useful for categorical data that doesn't have a lot of different categories (less than 30) because otherwise it can get very cluttered.
#
#
# - To plot a bar-chart in **Pandas** we can use the `plot.bar()` method, but before we can call this we need to get our data. For this we will first count the occurrences using the `value_count()` method and then sort the occurrences from smallest to largest using the `sort_index()` method.
#
#
#
# - In **Seaborn**, a bar chart can be created using the `sns.countplot` method and pass data to it.
# ---
# - Exercise 10 (Bar Plot using Matplotlib)
# - Exercise 11 (Bar Plot using Pandas visualization)
# - Exercise 12 (Bar Plot using Seaborn)
# - Now Your Turn 💪💪
# ---

# %% [markdown]
# ### Exercise 10 (Bar Plot using Matplotlib) 👇
# ---

# %%
cp.head(1)
# Out:
#    sl_no gender  ssc_p   ssc_b  hsc_p   hsc_b     hsc_s  degree_p  degree_t  \
# 0      1      M   67.0  Others   91.0  Others  Commerce      58.0  Sci&Tech
#
#   workex  etest_p specialisation  mba_p  status    salary
# 0     No     55.0         Mkt&HR   58.8  Placed  270000.0

# %%
####################################### Bar Plot using Matplotlib #########################################

# create a figure and axis 
fig, ax = plt.subplots() 
# count the occurrence of each class 
data = cp['gender'].value_counts()
# get x and y data 
points = data.index 
frequency = data.values 
# create bar chart 
ax.bar(points, frequency) 
# set title and labels 
for p in ax.patches:
    height = p.get_height()
    ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,s="{}%".format(height),ha='center')
ax.set_title('Gender Frequency')
ax.set_xlabel('Points') 
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# **Let's try to solve a simple example in different ways for the Bar plot 🤔🚀**

# %%
# Create simple dataset 
Math=np.random.randint(50,100,7)
Stat=np.random.randint(50,100,7)
CS=np.random.randint(50,100,7)
classes=list("ABCDEFG")

# %%
a4_dims = (8,8)
fig, ax = plt.subplots(figsize=a4_dims)
x_indeks=np.arange(len(classes))
plt.bar(classes, Math, label="Math Avg")
plt.bar(classes, Stat, label="Stat Avg")
plt.bar(classes, CS, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
plt.xticks(ticks=x_indeks, labels=classes)
# Out:
# ([<matplotlib.axis.XTick at 0x26e0ab09a30>,
# ...
#  [Text(0, 0, 'A'),
#   Text(1, 0, 'B'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'D'),
#   Text(4, 0, 'E'),
#   Text(5, 0, 'F'),
#   Text(6, 0, 'G')])

# %%
a4_dims = (8,8)
fig, ax = plt.subplots(figsize=a4_dims)
x_indeks=np.arange(len(classes))
x=0.25
plt.bar(x_indeks-x, Math, label="Math Avg")
plt.bar(x_indeks, Stat, label="Stat Avg")
plt.bar(x_indeks+x, CS, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
plt.xticks(ticks=x_indeks, labels=classes)
# Out:
# ([<matplotlib.axis.XTick at 0x26e0aba2400>,
# ...
#  [Text(0, 0, 'A'),
#   Text(1, 0, 'B'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'D'),
#   Text(4, 0, 'E'),
#   Text(5, 0, 'F'),
#   Text(6, 0, 'G')])

# %%
a4_dims = (8,8)
fig, ax = plt.subplots(figsize=a4_dims)
plt.bar(x_indeks-x,Math,width=x,label="Math Avg")
plt.bar(x_indeks, Stat, width=x,label="Stat Avg")
plt.bar(x_indeks+x, CS, width=x, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
plt.xticks(ticks=x_indeks, labels=classes)
# Out:
# ([<matplotlib.axis.XTick at 0x26e0ac33b50>,
# ...
#  [Text(0, 0, 'A'),
#   Text(1, 0, 'B'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'D'),
#   Text(4, 0, 'E'),
#   Text(5, 0, 'F'),
#   Text(6, 0, 'G')])

# %% [markdown]
# ### Exercise 11 (Bar Plot using Pandas visualization)👇
# ---

# %%
#################################### Bar Plot using Pandas visualization #####################################
ax = cp['gender'].value_counts().sort_index().plot.bar()
ax.set_title('Gender Frequency')
ax.set_xlabel('Points') 
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Exercise 12 (Bar Plot using Seaborn) 👇
# ---

# %%
####################################### Bar Plot using Seaborn #########################################
a4_dims = (5,.5)
fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.countplot(cp['gender'])
ax.set_title('Gender Frequency')
ax.set_xlabel('Points') 
ax.set_ylabel('Frequency')
# Out:
# C:\Users\h.eloqool.ext\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# #           ****************                               *****************
# #                              🥳🥳   Break 🥳🥳
#
# #           ****************                               *****************

# %% [markdown]
# ---
# ## <a id='pie'></a>Pie Plot
#
# - **Matplotlib** has `pie()` function in its `pyplot` module which create a pie chart representing the data in an array.
#
#
#
# - To plot a pie-chart in **Pandas** we can use the `plot.pie()` method, but before we can call this we need to get our data. For this we will first group by the occurrences using the `groupby()` method and then select one column and get it's sum using `sum()` method.
#
# ---
#
# - Exercise 13 (Pie Plot using Matplotlib)
# - Exercise 14 (Pie Plot using Pandas visualization)
# - Now Your Turn 💪💪
#
# ---

# %% [markdown]
# ### Exercise 13 (Pie Plot using Matplotlib)
# ---

# %%
####################################### Pie Plot using Matplotlib #########################################

# create a figure and axis 
fig, ax = plt.subplots() 
# count the occurrence of each class 
data = cp.groupby("gender")["salary"].sum()
# get x and y data 
points = data.index 
frequency = data.values
# create bar chart 
ax.pie(frequency, labels= points, autopct="%.1f%%") 
# set title and labels 
ax.set_title('Gender pie chart')
ax.legend(points)
ax.set_ylabel('salary')
# Out:
# Text(0, 0.5, 'salary')

# %% [markdown]
# ### Exercise 14 (Pie Plot using Pandas visualization)
# ---

# %%
#################################### Pie Plot using Pandas visualization #######################################

#groupby the data by delivery type
data = cp.groupby("gender")["salary"].sum()
data.plot.pie(autopct="%.1f%%");
ax.set_title('Gender pie chart')
# Out:
# Text(0.5, 1.0, 'Gender pie chart')

# %% [markdown]
# ### ⟹ Now Your Turn 💪💪🚀
#
# Use the company_sales_data.csv CSV file you used in your first turn to solve the following requirement.
# - Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk.
# - Read the total profit of each month and show it using the histogram to see the most common profit ranges.
# - Calculate total sale data for last year for each product and show it using a Pie chart.

# %%
# Write Your code 🚀🚀

### Read sales data of bathing soap of all months
# Start code

# End code

### Show sales data of bathing soap of all months using a bar plot.
# Start code

# End code

#========================================================================================================
### Read the total profit of each month
# Start code

# End code

### Show the total profit of each month using a histogram plot.
# Start code

# End code

#========================================================================================================

### Calculate total sale data for last year for each product
# Start code

# End code

### Show the total sale data for last year for each product using a pie chart.
# Start code

# End code

# %% [markdown]
# ---
# ## <a id='stem'></a>Stem Plot
#
# - To plot a stem plot in **Matplotlib**, we can use `stem()` method. It creates vertical lines from a baseline to the Y-coordinate and places a marker at the tip.
#
# ---

# %%
####################################### Stem Plot using Matplotlib #########################################
x = np.linspace(0.1, 2 * np.pi, 41)
y = np.exp(np.sin(x))


plt.stem(x, y, use_line_collection = True,linefmt='grey', markerfmt='*')
# set a title and labels
plt.title('Sin Function')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

markerline, stemlines, baseline = plt.stem(x, y, linefmt='grey', markerfmt='*', bottom=1.035)

markerline.set_markerfacecolor('red')
plt.title('Sin Function')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# # Good Luck 🤗 🤗 🤗
